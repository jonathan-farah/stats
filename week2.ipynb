# %%
import numpy as np
import pandas as pd


A = np.array([1,2,3,4,5,6,9])
B = np.array([6,7,8,9,10,2,4])
print(np.vstack((A,B)))
print(np.hstack((A,B)))
# Out:
# [[ 1  2  3  4  5  6  9]
#  [ 6  7  8  9 10  2  4]]
# [ 1  2  3  4  5  6  9  6  7  8  9 10  2  4]

# %%
from functools import reduce
print(np.intersect1d(A,B))
# Out:
# [2 4 6 9]

# %%
C = np.arange(10)
print(np.where((C > 5) & (C < 10)))
print(C[C < 5])
# Out:
# (array([6, 7, 8, 9], dtype=int64),)
# [0 1 2 3 4]

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0,1,2,3])

# %%
iris_2d
#petallength (3rd column) > 1.5 and sepallength (1st column) < 5.0
print(np.where())
iris_2d[(iris_2d[:,2] > 1.5) & (iris_2d[:,0] < 5.0)]
# Out:
# array([[4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.4, 1.9, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [4.9, 2.4, 3.3, 1. ],
#        [4.9, 2.5, 4.5, 1.7]])

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
data_arr=df.a
df2 = df[df.reset_index().index % 20 == 0] 
print(df2)
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 20     Chrysler  LeBaron  Compact       14.5   15.8       17.1      23.0
# 40        Honda  Prelude   Sporty       17.0   19.8       22.7      24.0
# 60      Mercury   Cougar  Midsize       14.9   14.9       14.9      19.0
# 80       Subaru   Loyale    Small       10.5   10.9       11.3      25.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0          31.0                 NaN      Front  ...        5.0   177.0
# 20         28.0  Driver & Passenger      Front  ...        6.0   183.0
# 40         31.0  Driver & Passenger      Front  ...        4.0   175.0
# 60         26.0                 NaN       Rear  ...        5.0   199.0
# 80         30.0                 NaN        4WD  ...        5.0   175.0
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
df(iris_2d[:,2] > 1.5) & (iris_2d[:,0] < 5.0)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8688\1166331599.py in ?()
#       1 import pandas as pd
#       2 import numpy as np
#       3 df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
# ----> 4 df = df.arrange()
#       5 df(iris_2d[:,2] > 1.5) & (iris_2d[:,0] < 5.0)
#       6 df
#
# c:\Users\jonat\New folder\New folder (2)\hw2\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'arrange'
